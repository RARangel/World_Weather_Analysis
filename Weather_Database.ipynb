# %%
# Import the  library.
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the API key.
from config import api_key

# %%
# Create a practice set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lon = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lon = zip(lat, lon)

# %%
#Convert to list
coordinates = list(lat_lon)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#Create a list for holding the cities
cities = []

#identify nearest city to lat-long
for coordinate in coordinates:
        city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

        #If city not unique then add to cities list
        if city not in cities:
            cities.append(city)
#Print city count
len(cities)
# Out:
# 755

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7050ec972e30cd5376f1e59c3b1ee70f

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_weather_description = city_weather["main"]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lon": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taltal
# Processing Record 2 of Set 1 | kristiinankaupunki
# Processing Record 3 of Set 1 | lethem
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | hambantota
# Processing Record 7 of Set 1 | paamiut
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | semnan
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | tutoia
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | marawi
# Processing Record 21 of Set 1 | bruiu
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | laguna
# Processing Record 24 of Set 1 | manta
# Processing Record 25 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 26 of Set 1 | pedernales
# Processing Record 27 of Set 1 | demba
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 1 | kedrovyy
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | stilfontein
# Processing Record 34 of Set 1 | touros
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | laela
# Processing Record 37 of Set 1 | lagoa
# Processing Record 38 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | marrakesh
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | bubaque
# Processing Record 43 of Set 1 | narsaq
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | mahanje
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | kulhudhuffushi
# Processing Record 48 of Set 1 | rocha
# Processing Record 49 of Set 1 | vila velha
# Processing Record 50 of Set 1 | kolokani
# Processing Record 1 of Set 2 | saint-ambroise
# Processing Record 2 of Set 2 | luderitz
# Processing Record 3 of Set 2 | urubamba
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | japura
# Processing Record 8 of Set 2 | saldanha
# Processing Record 9 of Set 2 | klaksvik
# Processing Record 10 of Set 2 | sokoni
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | aksu
# Processing Record 13 of Set 2 | comodoro rivadavia
# Processing Record 14 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 2 | mangrol
# Processing Record 16 of Set 2 | ostrovnoy
# Processing Record 17 of Set 2 | margate
# Processing Record 18 of Set 2 | odienne
# Processing Record 19 of Set 2 | kavaratti
# Processing Record 20 of Set 2 | vila franca do campo
# Processing Record 21 of Set 2 | beira
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | upington
# Processing Record 24 of Set 2 | mtwara
# Processing Record 25 of Set 2 | bonavista
# Processing Record 26 of Set 2 | ust-ishim
# Processing Record 27 of Set 2 | mecca
# Processing Record 28 of Set 2 | saint anthony
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | baran
# Processing Record 32 of Set 2 | oranjestad
# Processing Record 33 of Set 2 | boralday
# Processing Record 34 of Set 2 | skibbereen
# Processing Record 35 of Set 2 | porto novo
# Processing Record 36 of Set 2 | mananjary
# Processing Record 37 of Set 2 | sivas
# Processing Record 38 of Set 2 | krasnoselkup
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | yarmouth
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | taoudenni
# Processing Record 43 of Set 2 | peyima
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | novyy urengoy
# Processing Record 46 of Set 2 | general roca
# Processing Record 47 of Set 2 | mulchen
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | harrai
# Processing Record 50 of Set 2 | svetlyy
# Processing Record 1 of Set 3 | gidole
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | maniitsoq
# Processing Record 5 of Set 3 | hofn
# Processing Record 6 of Set 3 | lev tolstoy
# Processing Record 7 of Set 3 | amalapuram
# Processing Record 8 of Set 3 | cairo
# Processing Record 9 of Set 3 | anuradhapura
# Processing Record 10 of Set 3 | sinnamary
# Processing Record 11 of Set 3 | richards bay
# Processing Record 12 of Set 3 | sabattus
# Processing Record 13 of Set 3 | grindavik
# Processing Record 14 of Set 3 | acarau
# Processing Record 15 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 16 of Set 3 | chapais
# Processing Record 17 of Set 3 | dingle
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | leshukonskoye
# Processing Record 20 of Set 3 | nizwa
# Processing Record 21 of Set 3 | zimnicea
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | nylstroom
# City not found. Skipping...
# Processing Record 24 of Set 3 | freetown
# Processing Record 25 of Set 3 | tazovskiy
# Processing Record 26 of Set 3 | general pico
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | outjo
# Processing Record 30 of Set 3 | shahr-e babak
# Processing Record 31 of Set 3 | general elizardo aquino
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 3 | civitanova marche
# Processing Record 36 of Set 3 | jalu
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | iqaluit
# Processing Record 39 of Set 3 | kisangani
# Processing Record 40 of Set 3 | tromso
# Processing Record 41 of Set 3 | port hawkesbury
# Processing Record 42 of Set 3 | redcliffe
# Processing Record 43 of Set 3 | vestmannaeyjar
# Processing Record 44 of Set 3 | coromandel
# Processing Record 45 of Set 3 | san andres
# Processing Record 46 of Set 3 | quatre cocos
# Processing Record 47 of Set 3 | oktyabrskoye
# Processing Record 48 of Set 3 | havelock
# Processing Record 49 of Set 3 | braslav
# City not found. Skipping...
# Processing Record 50 of Set 3 | camacha
# Processing Record 1 of Set 4 | montepuez
# Processing Record 2 of Set 4 | tessalit
# Processing Record 3 of Set 4 | bluffton
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 4 | santa vitoria do palmar
# Processing Record 7 of Set 4 | murgab
# Processing Record 8 of Set 4 | nuuk
# Processing Record 9 of Set 4 | buzdyak
# Processing Record 10 of Set 4 | havre-saint-pierre
# Processing Record 11 of Set 4 | coxim
# Processing Record 12 of Set 4 | cayenne
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | valavanur
# Processing Record 16 of Set 4 | kangaatsiaq
# Processing Record 17 of Set 4 | vestmanna
# Processing Record 18 of Set 4 | carballo
# Processing Record 19 of Set 4 | yeovil
# Processing Record 20 of Set 4 | tonj
# Processing Record 21 of Set 4 | ratnagiri
# Processing Record 22 of Set 4 | mana
# Processing Record 23 of Set 4 | gat
# Processing Record 24 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 4 | arlit
# Processing Record 26 of Set 4 | riohacha
# Processing Record 27 of Set 4 | dawlatabad
# Processing Record 28 of Set 4 | methoni
# Processing Record 29 of Set 4 | kutum
# Processing Record 30 of Set 4 | murtino
# Processing Record 31 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 4 | tampere
# Processing Record 33 of Set 4 | opuwo
# Processing Record 34 of Set 4 | bathsheba
# Processing Record 35 of Set 4 | canavieiras
# Processing Record 36 of Set 4 | kruisfontein
# Processing Record 37 of Set 4 | alfafar
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | turukhansk
# Processing Record 40 of Set 4 | santa cruz
# Processing Record 41 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 4 | roald
# Processing Record 43 of Set 4 | pisco
# Processing Record 44 of Set 4 | masvingo
# Processing Record 45 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 4 | kaputa
# Processing Record 47 of Set 4 | sao pedro da aldeia
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | virginia beach
# Processing Record 50 of Set 4 | visnes
# Processing Record 1 of Set 5 | sao joao da barra
# Processing Record 2 of Set 5 | bandarbeyla
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 5 | trapani
# Processing Record 6 of Set 5 | salalah
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | north myrtle beach
# Processing Record 10 of Set 5 | luanda
# Processing Record 11 of Set 5 | porosozero
# Processing Record 12 of Set 5 | nouadhibou
# Processing Record 13 of Set 5 | kindu
# Processing Record 14 of Set 5 | kokologo
# Processing Record 15 of Set 5 | sortland
# Processing Record 16 of Set 5 | nacala
# Processing Record 17 of Set 5 | nokaneng
# Processing Record 18 of Set 5 | santa maria da boa vista
# Processing Record 19 of Set 5 | novonikolayevskiy
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | sidi ali
# Processing Record 22 of Set 5 | yar-sale
# Processing Record 23 of Set 5 | dikson
# Processing Record 24 of Set 5 | funtua
# Processing Record 25 of Set 5 | harper
# Processing Record 26 of Set 5 | puerto leguizamo
# Processing Record 27 of Set 5 | lavumisa
# Processing Record 28 of Set 5 | santiago del estero
# Processing Record 29 of Set 5 | peterhead
# Processing Record 30 of Set 5 | toktogul
# Processing Record 31 of Set 5 | gornoye loo
# Processing Record 32 of Set 5 | clonakilty
# Processing Record 33 of Set 5 | kavos
# Processing Record 34 of Set 5 | mayor pablo lagerenza
# Processing Record 35 of Set 5 | sidi qasim
# City not found. Skipping...
# Processing Record 36 of Set 5 | raudeberg
# Processing Record 37 of Set 5 | alekseyevka
# Processing Record 38 of Set 5 | abu kamal
# Processing Record 39 of Set 5 | usinsk
# Processing Record 40 of Set 5 | watsa
# Processing Record 41 of Set 5 | salgueiro
# Processing Record 42 of Set 5 | robertson
# Processing Record 43 of Set 5 | catamarca
# Processing Record 44 of Set 5 | turayf
# Processing Record 45 of Set 5 | trincomalee
# Processing Record 46 of Set 5 | pitea
# Processing Record 47 of Set 5 | uribia
# Processing Record 48 of Set 5 | port shepstone
# Processing Record 49 of Set 5 | bud
# Processing Record 50 of Set 5 | adrar
# Processing Record 1 of Set 6 | aksehir
# Processing Record 2 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 6 | bollnas
# Processing Record 4 of Set 6 | tabuk
# Processing Record 5 of Set 6 | goldap
# Processing Record 6 of Set 6 | oranjemund
# Processing Record 7 of Set 6 | progreso
# Processing Record 8 of Set 6 | ciudad bolivar
# Processing Record 9 of Set 6 | sambava
# Processing Record 10 of Set 6 | valparaiso
# Processing Record 11 of Set 6 | ikom
# Processing Record 12 of Set 6 | tupanatinga
# Processing Record 13 of Set 6 | madimba
# Processing Record 14 of Set 6 | pinega
# Processing Record 15 of Set 6 | mocuba
# Processing Record 16 of Set 6 | hobyo
# Processing Record 17 of Set 6 | loucovice
# Processing Record 18 of Set 6 | indergarh
# Processing Record 19 of Set 6 | bilma
# Processing Record 20 of Set 6 | kemijarvi
# Processing Record 21 of Set 6 | izmalkovo
# Processing Record 22 of Set 6 | vorukh
# Processing Record 23 of Set 6 | cabedelo
# Processing Record 24 of Set 6 | thompson
# Processing Record 25 of Set 6 | tahoua
# Processing Record 26 of Set 6 | kukmor
# Processing Record 27 of Set 6 | srivardhan
# Processing Record 28 of Set 6 | belyy yar
# Processing Record 29 of Set 6 | bodden town
# Processing Record 30 of Set 6 | marsa matruh
# Processing Record 31 of Set 6 | kargasok
# Processing Record 32 of Set 6 | swakopmund
# Processing Record 33 of Set 6 | goderich
# Processing Record 34 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 6 | meulaboh
# Processing Record 36 of Set 6 | ambilobe
# Processing Record 37 of Set 6 | iskateley
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | portree
# Processing Record 40 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 41 of Set 6 | tiznit
# Processing Record 42 of Set 6 | carupano
# Processing Record 43 of Set 6 | santa fe
# Processing Record 44 of Set 6 | key west
# Processing Record 45 of Set 6 | benghazi
# Processing Record 46 of Set 6 | gulbene
# Processing Record 47 of Set 6 | antalaha
# Processing Record 48 of Set 6 | tiebissou
# Processing Record 49 of Set 6 | esmeraldas
# Processing Record 50 of Set 6 | ballina
# Processing Record 1 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 2 of Set 7 | saint-leu
# Processing Record 3 of Set 7 | necochea
# Processing Record 4 of Set 7 | astana
# Processing Record 5 of Set 7 | staryy nadym
# Processing Record 6 of Set 7 | manicore
# Processing Record 7 of Set 7 | mandiana
# Processing Record 8 of Set 7 | mul
# Processing Record 9 of Set 7 | itaqui
# Processing Record 10 of Set 7 | saint george
# Processing Record 11 of Set 7 | camacupa
# Processing Record 12 of Set 7 | ugoofaaru
# Processing Record 13 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 7 | inyonga
# Processing Record 15 of Set 7 | teguldet
# Processing Record 16 of Set 7 | cozumel
# Processing Record 17 of Set 7 | khagaria
# Processing Record 18 of Set 7 | rosetta
# Processing Record 19 of Set 7 | dinguiraye
# Processing Record 20 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 7 | birao
# Processing Record 22 of Set 7 | gualeguay
# Processing Record 23 of Set 7 | kaminskiy
# Processing Record 24 of Set 7 | nelidovo
# Processing Record 25 of Set 7 | pasni
# Processing Record 26 of Set 7 | pleshanovo
# Processing Record 27 of Set 7 | ormara
# Processing Record 28 of Set 7 | wad madani
# Processing Record 29 of Set 7 | sosnovka
# Processing Record 30 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 31 of Set 7 | qaqortoq
# Processing Record 32 of Set 7 | saint pete beach
# Processing Record 33 of Set 7 | mao
# Processing Record 34 of Set 7 | monki
# Processing Record 35 of Set 7 | altay
# Processing Record 36 of Set 7 | barranca
# Processing Record 37 of Set 7 | madras
# Processing Record 38 of Set 7 | ravar
# Processing Record 39 of Set 7 | banepa
# Processing Record 40 of Set 7 | carora
# Processing Record 41 of Set 7 | marsh harbour
# Processing Record 42 of Set 7 | killybegs
# Processing Record 43 of Set 7 | boende
# Processing Record 44 of Set 7 | fraga
# Processing Record 45 of Set 7 | grand baie
# Processing Record 46 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 7 | el tigre
# Processing Record 49 of Set 7 | beloha
# Processing Record 50 of Set 7 | ondangwa
# Processing Record 1 of Set 8 | walvis bay
# Processing Record 2 of Set 8 | umea
# Processing Record 3 of Set 8 | snina
# Processing Record 4 of Set 8 | karpathos
# Processing Record 5 of Set 8 | kupino
# Processing Record 6 of Set 8 | conselheiro pena
# Processing Record 7 of Set 8 | sawakin
# Processing Record 8 of Set 8 | dale
# Processing Record 9 of Set 8 | trairi
# Processing Record 10 of Set 8 | makat
# Processing Record 11 of Set 8 | karksi-nuia
# Processing Record 12 of Set 8 | gasa
# Processing Record 13 of Set 8 | bonga
# Processing Record 14 of Set 8 | kurchum
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | birjand
# Processing Record 17 of Set 8 | alibag
# Processing Record 18 of Set 8 | garowe
# Processing Record 19 of Set 8 | pitimbu
# Processing Record 20 of Set 8 | barra patuca
# Processing Record 21 of Set 8 | alappuzha
# Processing Record 22 of Set 8 | pryamitsyno
# Processing Record 23 of Set 8 | burriana
# Processing Record 24 of Set 8 | cabras
# Processing Record 25 of Set 8 | limoeiro do ajuru
# Processing Record 26 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 8 | kudahuvadhoo
# Processing Record 28 of Set 8 | recas
# Processing Record 29 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 8 | ciudad real
# Processing Record 31 of Set 8 | arica
# Processing Record 32 of Set 8 | nordlingen
# City not found. Skipping...
# Processing Record 33 of Set 8 | ponta delgada
# Processing Record 34 of Set 8 | melbu
# Processing Record 35 of Set 8 | montepulciano
# Processing Record 36 of Set 8 | pangnirtung
# Processing Record 37 of Set 8 | korla
# Processing Record 38 of Set 8 | zandvoort
# Processing Record 39 of Set 8 | araguatins
# City not found. Skipping...
# Processing Record 40 of Set 8 | vysha
# Processing Record 41 of Set 8 | burica
# City not found. Skipping...
# Processing Record 42 of Set 8 | plettenberg bay
# Processing Record 43 of Set 8 | delijan
# Processing Record 44 of Set 8 | roros
# Processing Record 45 of Set 8 | san luis
# Processing Record 46 of Set 8 | la ferte-bernard
# Processing Record 47 of Set 8 | tekeli
# Processing Record 48 of Set 8 | atoka
# Processing Record 49 of Set 8 | teya
# Processing Record 50 of Set 8 | orbetello
# Processing Record 1 of Set 9 | krasnoye-na-volge
# Processing Record 2 of Set 9 | maracacume
# Processing Record 3 of Set 9 | warri
# Processing Record 4 of Set 9 | westport
# Processing Record 5 of Set 9 | aljezur
# Processing Record 6 of Set 9 | mendi
# Processing Record 7 of Set 9 | laguna de perlas
# Processing Record 8 of Set 9 | longido
# Processing Record 9 of Set 9 | luangwa
# Processing Record 10 of Set 9 | karasburg
# Processing Record 11 of Set 9 | kuytun
# Processing Record 12 of Set 9 | ilhabela
# Processing Record 13 of Set 9 | escanaba
# Processing Record 14 of Set 9 | santa rosa
# Processing Record 15 of Set 9 | cheremnoye
# Processing Record 16 of Set 9 | moundou
# Processing Record 17 of Set 9 | thohoyandou
# Processing Record 18 of Set 9 | sorland
# Processing Record 19 of Set 9 | pozo colorado
# Processing Record 20 of Set 9 | nara
# Processing Record 21 of Set 9 | codrington
# Processing Record 22 of Set 9 | radnevo
# Processing Record 23 of Set 9 | kisanga
# Processing Record 24 of Set 9 | kalangala
# Processing Record 25 of Set 9 | marsabit
# Processing Record 26 of Set 9 | abha
# Processing Record 27 of Set 9 | wilson
# Processing Record 28 of Set 9 | kinkala
# Processing Record 29 of Set 9 | stornoway
# Processing Record 30 of Set 9 | funchal
# Processing Record 31 of Set 9 | marmaris
# Processing Record 32 of Set 9 | obilnoye
# Processing Record 33 of Set 9 | kabo
# Processing Record 34 of Set 9 | saint-georges
# Processing Record 35 of Set 9 | henties bay
# Processing Record 36 of Set 9 | ardakan
# Processing Record 37 of Set 9 | bull savanna
# Processing Record 38 of Set 9 | alanya
# Processing Record 39 of Set 9 | naryan-mar
# Processing Record 40 of Set 9 | blytheville
# Processing Record 41 of Set 9 | esmeralda
# Processing Record 42 of Set 9 | nalut
# Processing Record 43 of Set 9 | pajarito
# Processing Record 44 of Set 9 | cap malheureux
# Processing Record 45 of Set 9 | bereda
# Processing Record 46 of Set 9 | lubango
# Processing Record 47 of Set 9 | lokosovo
# Processing Record 48 of Set 9 | igarka
# Processing Record 49 of Set 9 | beneditinos
# Processing Record 50 of Set 9 | sokolo
# Processing Record 1 of Set 10 | nioro
# Processing Record 2 of Set 10 | strezhevoy
# Processing Record 3 of Set 10 | agadir
# Processing Record 4 of Set 10 | fernan-nunez
# Processing Record 5 of Set 10 | havoysund
# Processing Record 6 of Set 10 | kibuye
# Processing Record 7 of Set 10 | matara
# Processing Record 8 of Set 10 | rudbar
# Processing Record 9 of Set 10 | passos
# Processing Record 10 of Set 10 | hurghada
# Processing Record 11 of Set 10 | tabou
# Processing Record 12 of Set 10 | itacarambi
# Processing Record 13 of Set 10 | porbandar
# Processing Record 14 of Set 10 | benicarlo
# Processing Record 15 of Set 10 | diffa
# Processing Record 16 of Set 10 | maldonado
# Processing Record 17 of Set 10 | houma
# Processing Record 18 of Set 10 | kaura namoda
# Processing Record 19 of Set 10 | elizabeth city
# Processing Record 20 of Set 10 | hagere hiywet
# Processing Record 21 of Set 10 | krutinka
# Processing Record 22 of Set 10 | jibuti
# Processing Record 23 of Set 10 | sisimiut
# Processing Record 24 of Set 10 | mahibadhoo
# Processing Record 25 of Set 10 | nyimba
# Processing Record 26 of Set 10 | biedenkopf
# Processing Record 27 of Set 10 | buraydah
# Processing Record 28 of Set 10 | bure
# Processing Record 29 of Set 10 | kalvarija
# Processing Record 30 of Set 10 | saint-paul
# Processing Record 31 of Set 10 | los llanos de aridane
# Processing Record 32 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 10 | lucapa
# Processing Record 34 of Set 10 | tucuman
# Processing Record 35 of Set 10 | saint-pierre
# Processing Record 36 of Set 10 | ephrata
# Processing Record 37 of Set 10 | tortona
# Processing Record 38 of Set 10 | maracas
# Processing Record 39 of Set 10 | damavand
# Processing Record 40 of Set 10 | olavarria
# Processing Record 41 of Set 10 | locri
# Processing Record 42 of Set 10 | kafue
# Processing Record 43 of Set 10 | at-bashi
# Processing Record 44 of Set 10 | praia
# Processing Record 45 of Set 10 | west bend
# Processing Record 46 of Set 10 | baie-comeau
# Processing Record 47 of Set 10 | inzer
# Processing Record 48 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 10 | cookeville
# Processing Record 50 of Set 10 | paulo ramos
# Processing Record 1 of Set 11 | bosaso
# Processing Record 2 of Set 11 | aboisso
# Processing Record 3 of Set 11 | saint-joseph
# Processing Record 4 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 11 | muborak
# Processing Record 6 of Set 11 | puerto colombia
# Processing Record 7 of Set 11 | knysna
# Processing Record 8 of Set 11 | kongolo
# Processing Record 9 of Set 11 | eidfjord
# Processing Record 10 of Set 11 | itupiranga
# Processing Record 11 of Set 11 | kiboga
# Processing Record 12 of Set 11 | kathu
# Processing Record 13 of Set 11 | dhidhdhoo
# Processing Record 14 of Set 11 | riviere-au-renard
# Processing Record 15 of Set 11 | muisne
# Processing Record 16 of Set 11 | tarko-sale
# Processing Record 17 of Set 11 | timizart
# Processing Record 18 of Set 11 | rio gallegos
# Processing Record 19 of Set 11 | srednyaya yelyuzan
# Processing Record 20 of Set 11 | severnoye
# Processing Record 21 of Set 11 | bulungu
# Processing Record 22 of Set 11 | tete
# Processing Record 23 of Set 11 | koslan
# Processing Record 24 of Set 11 | kalmunai
# Processing Record 25 of Set 11 | tervel
# Processing Record 26 of Set 11 | talara
# Processing Record 27 of Set 11 | igrim
# Processing Record 28 of Set 11 | muhos
# Processing Record 29 of Set 11 | farafangana
# Processing Record 30 of Set 11 | plonsk
# Processing Record 31 of Set 11 | angoche
# Processing Record 32 of Set 11 | harboore
# Processing Record 33 of Set 11 | rassvet
# Processing Record 34 of Set 11 | saint-francois
# Processing Record 35 of Set 11 | conakry
# Processing Record 36 of Set 11 | auchi
# Processing Record 37 of Set 11 | bria
# Processing Record 38 of Set 11 | summerville
# Processing Record 39 of Set 11 | kenitra
# Processing Record 40 of Set 11 | maceio
# Processing Record 41 of Set 11 | diplo
# Processing Record 42 of Set 11 | corinto
# Processing Record 43 of Set 11 | nantucket
# Processing Record 44 of Set 11 | jablah
# Processing Record 45 of Set 11 | sudzha
# Processing Record 46 of Set 11 | jardim
# Processing Record 47 of Set 11 | tabora
# Processing Record 48 of Set 11 | aranos
# Processing Record 49 of Set 11 | vardo
# Processing Record 50 of Set 11 | bhitarwar
# Processing Record 1 of Set 12 | bequimao
# Processing Record 2 of Set 12 | asifabad
# Processing Record 3 of Set 12 | urengoy
# Processing Record 4 of Set 12 | san vicente de canete
# Processing Record 5 of Set 12 | oneonta
# Processing Record 6 of Set 12 | coruripe
# Processing Record 7 of Set 12 | kamenka
# Processing Record 8 of Set 12 | straumen
# Processing Record 9 of Set 12 | bloomington
# Processing Record 10 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 12 | carmarthen
# Processing Record 12 of Set 12 | xapuri
# Processing Record 13 of Set 12 | huarmey
# Processing Record 14 of Set 12 | champua
# Processing Record 15 of Set 12 | jacqueville
# Processing Record 16 of Set 12 | paita
# Processing Record 17 of Set 12 | peniche
# Processing Record 18 of Set 12 | portlethen
# Processing Record 19 of Set 12 | marathon
# Processing Record 20 of Set 12 | charyshskoye
# Processing Record 21 of Set 12 | kabompo
# Processing Record 22 of Set 12 | kobryn
# Processing Record 23 of Set 12 | guhagar
# Processing Record 24 of Set 12 | uray
# Processing Record 25 of Set 12 | djambala
# Processing Record 26 of Set 12 | kinwat
# Processing Record 27 of Set 12 | mekhe
# Processing Record 28 of Set 12 | beyneu
# Processing Record 29 of Set 12 | funes
# Processing Record 30 of Set 12 | butterworth
# Processing Record 31 of Set 12 | trinidad
# Processing Record 32 of Set 12 | bondo
# Processing Record 33 of Set 12 | coquimbo
# Processing Record 34 of Set 12 | mungwi
# Processing Record 35 of Set 12 | fulton
# Processing Record 36 of Set 12 | mezen
# Processing Record 37 of Set 12 | monte cristi
# City not found. Skipping...
# Processing Record 38 of Set 12 | surt
# Processing Record 39 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 12 | ginir
# Processing Record 41 of Set 12 | thinadhoo
# Processing Record 42 of Set 12 | domoni
# Processing Record 43 of Set 12 | strandby
# Processing Record 44 of Set 12 | odweyne
# Processing Record 45 of Set 12 | swiecie
# Processing Record 46 of Set 12 | ust-kan
# Processing Record 47 of Set 12 | ampanihy
# Processing Record 48 of Set 12 | umm lajj
# Processing Record 49 of Set 12 | shiringushi
# Processing Record 50 of Set 12 | gbadolite
# Processing Record 1 of Set 13 | morecambe
# Processing Record 2 of Set 13 | lac-megantic
# Processing Record 3 of Set 13 | menongue
# Processing Record 4 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 5 of Set 13 | gazli
# Processing Record 6 of Set 13 | teramo
# Processing Record 7 of Set 13 | isiro
# Processing Record 8 of Set 13 | mahabaleshwar
# Processing Record 9 of Set 13 | tighina
# Processing Record 10 of Set 13 | segezha
# Processing Record 11 of Set 13 | karata
# Processing Record 12 of Set 13 | suda
# Processing Record 13 of Set 13 | mitu
# Processing Record 14 of Set 13 | priyutnoye
# Processing Record 15 of Set 13 | synya
# Processing Record 16 of Set 13 | barsovo
# Processing Record 17 of Set 13 | uruacu
# Processing Record 18 of Set 13 | usogorsk
# Processing Record 19 of Set 13 | aquiraz
# Processing Record 20 of Set 13 | mangan
# Processing Record 21 of Set 13 | abu dhabi
# Processing Record 22 of Set 13 | pombas
# Processing Record 23 of Set 13 | belmonte
# Processing Record 24 of Set 13 | chipinge
# Processing Record 25 of Set 13 | cubuk
# Processing Record 26 of Set 13 | kjollefjord
# Processing Record 27 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 13 | gao
# Processing Record 29 of Set 13 | inhambane
# Processing Record 30 of Set 13 | omboue
# Processing Record 31 of Set 13 | chabahar
# Processing Record 32 of Set 13 | atasu
# Processing Record 33 of Set 13 | sao domingos
# Processing Record 34 of Set 13 | uravakonda
# Processing Record 35 of Set 13 | stephanskirchen
# Processing Record 36 of Set 13 | saquarema
# Processing Record 37 of Set 13 | vallenar
# Processing Record 38 of Set 13 | san ramon
# Processing Record 39 of Set 13 | hare bay
# Processing Record 40 of Set 13 | san carlos del zulia
# Processing Record 41 of Set 13 | olinda
# Processing Record 42 of Set 13 | chandrakona
# Processing Record 43 of Set 13 | szombathely
# Processing Record 44 of Set 13 | rafaela
# Processing Record 45 of Set 13 | troitsko-pechorsk
# Processing Record 46 of Set 13 | wagar
# Processing Record 47 of Set 13 | polovinnoye
# Processing Record 48 of Set 13 | waw
# Processing Record 49 of Set 13 | easton
# Processing Record 50 of Set 13 | cordoba
# Processing Record 1 of Set 14 | gorgan
# Processing Record 2 of Set 14 | rorvik
# Processing Record 3 of Set 14 | brigantine
# Processing Record 4 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 5 of Set 14 | camocim
# Processing Record 6 of Set 14 | muscat
# Processing Record 7 of Set 14 | arenapolis
# Processing Record 8 of Set 14 | edgewater
# Processing Record 9 of Set 14 | lesnyye polyany
# Processing Record 10 of Set 14 | tayibe
# City not found. Skipping...
# Processing Record 11 of Set 14 | grand-santi
# Processing Record 12 of Set 14 | puerto maldonado
# Processing Record 13 of Set 14 | stepnyak
# Processing Record 14 of Set 14 | satipo
# Processing Record 15 of Set 14 | novominskaya
# Processing Record 16 of Set 14 | montague
# Processing Record 17 of Set 14 | rawson
# Processing Record 18 of Set 14 | salinopolis
# Processing Record 19 of Set 14 | gopalur
# Processing Record 20 of Set 14 | nicolas bravo
# Processing Record 21 of Set 14 | hearst
# Processing Record 22 of Set 14 | mitsamiouli
# Processing Record 23 of Set 14 | bourbonnais
# Processing Record 24 of Set 14 | tukan
# Processing Record 25 of Set 14 | anloga
# Processing Record 26 of Set 14 | marienburg
# Processing Record 27 of Set 14 | ushtobe
# Processing Record 28 of Set 14 | beawar
# Processing Record 29 of Set 14 | brae
# Processing Record 30 of Set 14 | viedma
# Processing Record 31 of Set 14 | aksarayskiy
# Processing Record 32 of Set 14 | zurrieq
# Processing Record 33 of Set 14 | springdale
# Processing Record 34 of Set 14 | kiruna
# Processing Record 35 of Set 14 | dalvik
# Processing Record 36 of Set 14 | kalaleh
# Processing Record 37 of Set 14 | halkirk
# Processing Record 38 of Set 14 | kalavai
# Processing Record 39 of Set 14 | severomorsk
# Processing Record 40 of Set 14 | bardiyah
# Processing Record 41 of Set 14 | jensen beach
# Processing Record 42 of Set 14 | manadhoo
# Processing Record 43 of Set 14 | oxelosund
# Processing Record 44 of Set 14 | copiapo
# Processing Record 45 of Set 14 | cacoal
# Processing Record 46 of Set 14 | muzaffarabad
# Processing Record 47 of Set 14 | pangody
# Processing Record 48 of Set 14 | bonthe
# Processing Record 49 of Set 14 | sao jose do egito
# Processing Record 50 of Set 14 | marovoay
# Processing Record 1 of Set 15 | banda aceh
# Processing Record 2 of Set 15 | joshimath
# Processing Record 3 of Set 15 | maragheh
# Processing Record 4 of Set 15 | dutse
# Processing Record 5 of Set 15 | puerto baquerizo moreno
# Processing Record 6 of Set 15 | itigi
# Processing Record 7 of Set 15 | windhoek
# Processing Record 8 of Set 15 | sompeta
# Processing Record 9 of Set 15 | surab
# Processing Record 10 of Set 15 | nautanwa
# Processing Record 11 of Set 15 | znamenskoye
# Processing Record 12 of Set 15 | rehnan
# Processing Record 13 of Set 15 | akdepe
# Processing Record 14 of Set 15 | santa cruz cabralia
# Processing Record 15 of Set 15 | akdagmadeni
# Processing Record 16 of Set 15 | tshela
# Processing Record 17 of Set 15 | glens falls
# Processing Record 18 of Set 15 | suffolk
# Processing Record 19 of Set 15 | qasigiannguit
# Processing Record 20 of Set 15 | syracuse
# Processing Record 21 of Set 15 | seoni
# Processing Record 22 of Set 15 | yakhroma
# Processing Record 23 of Set 15 | aleksandriya
# Processing Record 24 of Set 15 | isiolo
# Processing Record 25 of Set 15 | cabo rojo
# Processing Record 26 of Set 15 | liuli
# Processing Record 27 of Set 15 | asyut
# Processing Record 28 of Set 15 | abu samrah
# Processing Record 29 of Set 15 | blagoyevo
# Processing Record 30 of Set 15 | jacareacanga
# Processing Record 31 of Set 15 | mosquera
# Processing Record 32 of Set 15 | kita
# Processing Record 33 of Set 15 | bengkulu
# Processing Record 34 of Set 15 | bonfim
# Processing Record 35 of Set 15 | puri
# Processing Record 36 of Set 15 | balsas
# Processing Record 37 of Set 15 | mogilno
# Processing Record 38 of Set 15 | gbarnga
# Processing Record 39 of Set 15 | cobija
# Processing Record 40 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 15 | sabla
# Processing Record 42 of Set 15 | urumqi
# Processing Record 43 of Set 15 | kushnarenkovo
# Processing Record 44 of Set 15 | campina verde
# Processing Record 45 of Set 15 | bjornevatn
# Processing Record 46 of Set 15 | konotop
# Processing Record 47 of Set 15 | sechura
# Processing Record 48 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 49 of Set 15 | aligudarz
# Processing Record 50 of Set 15 | matagami
# Processing Record 1 of Set 16 | sucua
# Processing Record 2 of Set 16 | mayumba
# Processing Record 3 of Set 16 | chiscani
# Processing Record 4 of Set 16 | digby
# Processing Record 5 of Set 16 | praia da vitoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lon  Max Temp  Humidity  Cloudiness  \
# 0              Taltal -25.4000  -70.4833     69.75        71          24
# 1  Kristiinankaupunki  62.2743   21.3760     26.42        91          48
# 2              Lethem   3.3803  -59.7968     92.19        43         100
# 3            Hermanus -34.4187   19.2345     60.80        61         100
# 4          Hambantota   6.1241   81.1185     77.67        80          75
# 5             Paamiut  61.9940  -49.6678     14.47        85         100
# 6                Chuy -33.6971  -53.4616     69.58        55           4
# 7      Port Elizabeth -33.9180   25.5701     64.69        94          75
# 8           Busselton -33.6500  115.3333     63.68        88          11
# 9             Qaanaaq  77.4840  -69.3632     -9.02        92         100
#
#    Wind Speed Country                 Date
# 0        6.87      CL  2022-03-13 19:45:13
# 1        5.35      FI  2022-03-13 19:45:14
# 2        9.01      GY  2022-03-13 19:45:14
# 3       15.28      ZA  2022-03-13 19:43:30
# 4        9.44      LK  2022-03-13 19:45:15
# 5       18.23      GL  2022-03-13 19:45:15
# 6        9.08      UY  2022-03-13 19:45:15
# 7       16.11      ZA  2022-03-13 19:45:16
# 8        7.99      AU  2022-03-13 19:45:16
# 9        5.70      GL  2022-03-13 19:45:16

# %%
new_column_order = ["City", "Country", "Lat", "Lon", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lon  Max Temp  Humidity  \
# 0              Taltal      CL -25.4000  -70.4833     69.75        71
# 1  Kristiinankaupunki      FI  62.2743   21.3760     26.42        91
# 2              Lethem      GY   3.3803  -59.7968     92.19        43
# 3            Hermanus      ZA -34.4187   19.2345     60.80        61
# 4          Hambantota      LK   6.1241   81.1185     77.67        80
# 5             Paamiut      GL  61.9940  -49.6678     14.47        85
# 6                Chuy      UY -33.6971  -53.4616     69.58        55
# 7      Port Elizabeth      ZA -33.9180   25.5701     64.69        94
# 8           Busselton      AU -33.6500  115.3333     63.68        88
# 9             Qaanaaq      GL  77.4840  -69.3632     -9.02        92
#
#    Cloudiness  Wind Speed                 Date
# 0          24        6.87  2022-03-13 19:45:13
# 1          48        5.35  2022-03-13 19:45:14
# 2         100        9.01  2022-03-13 19:45:14
# 3         100       15.28  2022-03-13 19:43:30
# 4          75        9.44  2022-03-13 19:45:15
# 5         100       18.23  2022-03-13 19:45:15
# 6           4        9.08  2022-03-13 19:45:15
# 7          75       16.11  2022-03-13 19:45:16
# 8          11        7.99  2022-03-13 19:45:16
# 9         100        5.70  2022-03-13 19:45:16

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
